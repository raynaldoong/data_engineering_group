# %%
# !pip install apache-airflow
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 40.9 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached apache_airflow_providers_imap-3.1.1-py3-none-any.whl (17 kB)
# ...

# %%
# !airflow db init
# !airflow users create --username admin --password 12345678 --firstname FIRST_NAME --lastname LAST_NAME --role Admin --email admin@example.com
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)
# DB: sqlite:////home/faculty/airflow/airflow.db
# [2023-05-01T19:26:44.623+0000] {migration.py:207} INFO - Context impl SQLiteImpl.
# ...

# %%
# !pip install papermill
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)
# ...

# %%
# !mkdir /project/dags
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)
# mkdir: cannot create directory ‘/project/dags’: File exists

# %%
# !cd /project/dags
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)

# %%
# !airflow scheduler
# Out:
# /bin/bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
#
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# bash: /opt/anaconda/envs/Python3/lib/libtinfo.so.6: no version information available (required by bash)
#
# Please confirm database upgrade (or wait 4 seconds to skip it). Are you sure? [y/N]
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ...
